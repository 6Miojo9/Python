# %%
import os
import pandas as pd

grupo = "20"
data = "2701"
pasta = "G" + grupo + " " + data

arquivos = [(f, os.path.getsize(os.path.join(pasta, f))) for f in os.listdir(pasta) if os.path.isfile(os.path.join(pasta, f))]

df = pd.DataFrame(arquivos, columns=["Arquivo", "Tamanho"])

normal = df.at[0, "Arquivo"]
publico = df.at[1, "Arquivo"]

normal_df = pd.read_excel((pasta + "/" + normal), header=3)
publico_df = pd.read_excel((pasta + "/" + publico), header=3)

retidas = pd.concat([normal_df, publico_df], ignore_index=True)

retidas.to_excel("retidas.xlsx", index=False)
# Out:
# c:\Users\Gadyel\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\Gadyel\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      Uni. Organizacional                  ATC  Numero do TACE  \
# 0          00001192-OTMJ         ATC RUBINEIA          508592
# 1          00001192-OTMJ         ATC RUBINEIA          508592
# 2          00001192-OTMJ         ATC RUBINEIA          508592
# 3          00001192-OTMJ         ATC RUBINEIA          508592
# 4          00001192-OTMJ         ATC RUBINEIA          508592
# ...                  ...                  ...             ...
# ...
